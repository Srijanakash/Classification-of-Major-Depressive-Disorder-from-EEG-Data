# %%
import matplotlib.pyplot as plt

# %%
X=[4,5,6,7,8,9,10,11,12]
Y=[0.338041,0.330093,0.328783,0.248084,0.125966,0.122029,0.040962,0.000002,2.769*10**-7]
Y1=[1.2144,1.9218,2.3935,1.654,2.6191,37.2064,22.8957,1.7482,1.1585]
Y2=[0.376415,0.34482,0.33349,0.26017,0.226507,0.067408,0.007553,0.000023,0.000006]
Y3=[0.4707,0.63585,1.12185,1.2612,4.5284,20.0511,24.1189,8.6011,1.9956]

# %%
plt.plot(X,Y,label="Training Curve FCM")
plt.plot(X,Y2,label="Training curve Sub Clustering")
plt.xlabel("No of electrodes")
plt.ylabel("RMSE")
plt.legend()
plt.show()
plt.plot(X,Y1,label="Validation Curve FCM")
plt.plot(X,Y3,label="Validation curve Sub Clustering")
plt.xlabel("No of electrodes")
plt.ylabel("RMSE")
plt.legend()
plt.show()

# %%
X1=[4,5,6,7]
trimfY=[0.334433,0.25578,0.1599,0.020176]
gaussmfY=[0.315,0.21284,0.13615,0.016391]
trapmfY=[0.4088,0.34879,0.3075,0.16838]
gbellmfY=[0.32826,0.21961,0.15073,0.02182]
pimfY=[0.40864,0.34611,0.32945,0.21545]
dsigmfY=[0.38605,0.32321,0.24847,0.12249]
trimfY1=[1.9654,3.6095,0.15943,1.2247]
gaussmfY1=[10.70718,4.9168,0.13535,1.4727]
trapmfY1=[0.46352,2.8646,0.30203,2.3704]
gbellmfY1=[9.856,6.891,0.14944,1.5248]
pimfY1=[0.69803,1.1778,0.328,2.3085]
dsigmfY1=[2.7637,6.2662,0.2468,9.5627]

# %%
plt.plot(X1,trimfY,label='trimf')
plt.plot(X1,gaussmfY,label='gaussmf')
plt.plot(X1,trapmfY,label='trapmf')
plt.plot(X1,gbellmfY,label='gbell')
plt.plot(X1,pimfY,label='pimf')
plt.plot(X1,dsigmfY,label='dsigmf')
plt.legend()
plt.xlabel("No of electrodes")
plt.ylabel("RMSE")
plt.title("Training curves for Grid Partitioning")
plt.show()

# %%
plt.plot(X1,trimfY1,label='trimf')
plt.plot(X1,gaussmfY1,label='gaussmf')
plt.plot(X1,trapmfY1,label='trapmf')
plt.plot(X1,gbellmfY1,label='gbell')
plt.plot(X1,pimfY1,label='pimf')
plt.plot(X1,dsigmfY1,label='dsigmf')
plt.legend()
plt.xlabel("No of electrodes")
plt.ylabel("RMSE")
plt.title("Validation curves for Grid Partitioning")
plt.show()
